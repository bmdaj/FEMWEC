# %%
import numpy as np
from solver import freq_top_opt_2D
import matplotlib.pyplot as plt
# %matplotlib inline
verbose = False
if not verbose:
    import warnings
    warnings.filterwarnings("ignore")

# %%
res  =  0.05 # inverse of resolution
scaling = res*1e-6 # the scale applied to the physical problem
nElx =  int(14/res) # the number of elements in the X axis
nEly=  int(4/res) # the number of elements in the Y axis
nodesX = nElx + 1
nodesY = nEly + 1
print("scaling", scaling)

nodesX_EM = nodesX
nodesY_EM = nodesY
nodesX_heat = nodesX
nodesY_heat = nodesY
# Out:
# scaling 5e-08

# %%
print(nElx, nEly)
# Out:
# 280 80

# %%
n_metal = 3.1477 # refractive index for TiN
k_r =  5.8429  # exctinction coefficient for TiN
n_wg  = np.sqrt(15.054) # refractive index of the waveguide
n_clad = np.sqrt(4.2) # refractive index of cladding
dz = 200E-6
h_core = 1e-6 / scaling
w_core = 10e-6 / scaling  #10e-6 / scaling

# %%
wl = 1.55 / res #1.55 / res  # value for the wavelentgth, i.e. 1.55 um.
k = 2 * np.pi / (wl * scaling) # value of the wavevector
delta = 3.8193 #3.81969697 #3.82015075 #3.8204 #3.82104208  #3.818  # Effective refractive index from COMSOL
deltaT = 3.8208 #3.820100 #3.85787879#3.82155779#3.82111111 #3.82155779 #3.82155779 # previous: 3.8624
print("Initial effective index: ", delta)
print("Heated effective index: ", deltaT)
# Out:
# Initial effective index:  3.8193
# Heated effective index:  3.8208

# %%
fR = 4 # value for the filtering radius   
maxItr = 50  # number of iterations performed by the optimizer
alg = "MMA" # algorithm: Method of  Moving Asymptotes
eta = 0.5 # parameter that controls threshold value.
beta = 5 # parameter that controls threshold sharpness.
FOM_type = "linear"
tol = 1e-8

# %%
dVini_Omega_1 = 0.0 # intial value of design parameters in Omega_1
dVini_Omega_3 = 0.0 # intial value of design parameters in Omega_3
nEl_Omega_3 = 0

# %%
nEly_heat = nEly
nElx_heat = nElx
nEly_EM = nEly
nElx_EM = nElx


volume1  = np.zeros((nEly_heat, nElx_heat))
volume2  = np.zeros((nEly_heat, nElx_heat))
volume4  = np.zeros((nEly_heat, nElx_heat))
volume5  = np.zeros((nEly_heat, nElx_heat))


volume3 = np.zeros((nEly_heat+1, nElx_heat+1))

h_domain = 4E-6 / scaling#10e-6
alpha = 0.0

w_non_design = w_core + alpha * (h_domain-h_core)
h_non_design = h_core + alpha * (h_domain-h_core)

w_design_limit = nElx_EM 
h_design_limit = nEly_EM


volume1 [nEly_heat//2 - int(0.5*h_core) : nEly_heat//2 + int(0.5*h_core),nElx_heat//2 - int(0.5*w_core) : nElx_heat//2 + int(0.5*w_core)] = 1 # waveguide region
volume4 [nEly_heat//2 - int(0.5*h_non_design) : nEly_heat//2 + int(0.5*h_non_design),nElx_heat//2 - int(0.5*w_non_design) : nElx_heat//2 + int(0.5*w_non_design)] = 1
volume5 [nEly_heat//2 - h_design_limit//2 :nEly_heat//2 + h_design_limit//2 ,nElx_heat//2 - w_design_limit//2 : nElx_heat//2 + w_design_limit//2] = 1 
volume5 = volume5 - volume4

print(np.shape(volume4 [nEly_heat//2 - int(0.5*h_non_design) : nEly_heat//2 + int(0.5*h_non_design),nElx_heat//2 - int(0.5*w_non_design) : nElx_heat//2 + int(0.5*w_non_design)]))
print(np.shape(volume5 [nEly_heat//2 - h_design_limit//2 :nEly_heat//2 + h_design_limit//2 ,nElx_heat//2 - w_design_limit//2 : nElx_heat//2 + w_design_limit//2]))


indexes_design_limit = np.array(np.where(volume5<1))
volume4 [indexes_design_limit[0,:], indexes_design_limit[1,:]] = 1

volume3 [(nEly_heat+1)//2 - int(0.5*h_core) : (nEly_heat+1)//2 + int(0.5*h_core),(nElx_heat+1)//2 - int(0.5*w_core) : (nElx_heat+1)//2 + int(0.5*w_core)] = 1 # waveguide region
indexes_heating = np.array(np.where(volume3 > 0.5))
indexes_design_region_heat = np.array(np.where(volume5 == 1))
indexes_RHS = np.array(np.where(volume3 < 1))

indexes_wg_heat = np.array(np.where(volume3 == 1))


volume2 [nEly_heat//2 - int(0.5*h_core)-nEl_Omega_3:nEly_heat//2 + int(0.5*h_core)+nEl_Omega_3,nElx_heat//2 - int(0.5*w_core)-nEl_Omega_3:nElx_heat//2 + int(0.5*w_core)+nEl_Omega_3] = 1 # non-constraint region
volume3 = volume2 - volume1
indexes_heating_heat = np.array(np.where(volume3 > 0.5))
from wg_index import calc_index_constraint
indexes_constraint = (calc_index_constraint(indexes_design_region_heat, indexes_heating_heat)).astype(int)

dVini = dVini_Omega_1 *  np.ones_like(np.array(indexes_design_region_heat[0,:]).flatten()) 
dVini [indexes_constraint]= dVini_Omega_3

h_metal = 0.5E-6 / scaling#0.25E-6 / scaling
w_metal = 8E-6 / scaling#4E-6 / scaling
volume4 [:, :] = 0.0
volume4 [nEly//2 + int(0.5*h_core) : nEly//2 + int(0.5*h_core) + int(h_metal) , nElx//2 - int(0.5*w_core) : nElx//2 - int(0.5*w_core) + int(w_metal)] = 1 # metal region
indexes_metal = np.array(np.where(volume4 > 0.5))

from wg_index import calc_index_constraint

indexes_constraint = (calc_index_constraint(indexes_design_region_heat, indexes_heating)).astype(int)
indexes_metal_heater = (calc_index_constraint(indexes_design_region_heat, indexes_metal)).astype(int)
dVini = dVini_Omega_1 *  np.ones_like(np.array(indexes_design_region_heat[0,:]).flatten()) 
dVini[:] = 0.5
#dVini [indexes_metal_heater]= 1.0
volume1_heat = volume1


random = False
if random:
    np.random.seed(42)
    dVini = np.random.rand(len(dVini))
# Out:
# (20, 200)
# (80, 280)

# %%
indexes_design_region_EM = indexes_design_region_heat
indexes_wg_EM = indexes_wg_heat
indexes_heating_EM = indexes_heating_heat

# %%
vol_cons_val = 0.2
heat_cons_val =  0.0

# %%
RHS_heater = indexes_wg_heat
val_heater = 20e-3 * np.ones_like(indexes_design_region_heat)
#dz = 200e-6
k_wg = 148 
k_clad = 1.38 
k_metal = 28

# %%
print('Lenght of simulation domain in X: ', nElx_EM*scaling)
print('Lenght of simulation domain in Y: ', nEly_EM*scaling)
print('Wavelength of the problem: ', wl*scaling)
print('Dielectric constant (real part) of metal: ', n_metal**2)
# Out:
# Lenght of simulation domain in X:  1.4e-05
# Lenght of simulation domain in Y:  4e-06
# Wavelength of the problem:  1.55e-06
# Dielectric constant (real part) of metal:  9.90801529

# %%
L = dz

phase_shift = (deltaT-delta)*(2*np.pi*L)/(wl*scaling)
print("Phase-shift: ", str(phase_shift)+"  rad")
# Out:
# Phase-shift:  1.2161003820348046  rad

# %%
solver = freq_top_opt_2D( nElx_EM, 
                          nEly_EM,
                          nElx_heat, 
                          nEly_heat,
                          dVini,
                          w_core,
                          h_core,
                          n_metal,
                          k_r,
                          n_wg,
                          n_clad,
                          wl,
                          delta,
                          deltaT,  
                          fR,
                          eta,
                          beta,
                          scaling,
                          vol_cons_val,
                          FOM_type,
                          indexes_wg_EM,
                          indexes_wg_heat,
                          indexes_design_region_EM,
                          indexes_design_region_heat,
                          heat_cons_val,
                          indexes_heating_EM,
                          indexes_heating_heat,
                          continuation_scheme= True,
                          heating_constraint= False,
                          volume_constraint= False,
                          eliminate_excitation= False,
                          alpha = alpha,
                          dz=dz,
                          k_wg = k_wg,
                          k_clad = k_clad,
                          k_metal = k_metal,
                          debug=False,
                          logfile=True,
                          #low = low,
                          #upp = upp,
                          #raa = raa,
                         # raa0 = raa0,
                          #xold1 = xold1,
                          #xold2 = xold2,
                          #outit = outit
                        )
# Out:
# EDGE NUMBERING: (MAX, MIN):
# 45159.0
# 0.0

# %%
dVs = dVini
#dVs [:] = 0.5
T = solver.solve_heat(dVs, solver, idx_RHS = indexes_design_region_heat, val_RHS=val_heater)

# %%
#solver.plot_index_change()

# %%
solver.plot_material_interpolation()

# %% [markdown]
# ## Solution to coupled problem

# %%
print(np.shape(indexes_design_region_EM))
print(np.shape(indexes_design_region_heat))
print(np.shape(dVs))
# Out:
# (2, 18400)
# (2, 18400)
# (18400,)

# %%
N_edges =  nElx * (nEly+1) +  nEly * (nElx+1)
num_nodes_Q8 = (2 * nElx +1) * (nEly + 1) + (nElx+1) * nEly


node_RHS =   int(0.5*N_edges+0.1428*nElx) #int(0.5*N_edges+0.1428*nElx) #int(N_edges + 0.5*num_nodes_Q8 + 0.5 * 0.325*(2 * nElx +1))
idx_RHS_EM = np.array([node_RHS]).astype(int) #np.array([node_RHS]).astype(int) #np.array([node_RHS, node_RHS-0.5*nodesX+1]).astype(int)
val_RHS_EM = np.array([1-1j]) # np.array([0.5E-5*(1+0.5E-4j)]) * 10 #np.array([0.5E-5*(1+0.5E-4j), -0.5E-5*(1+0.5E-4j)]) * 10

solver.solve_coupled(dVs, solver='RHS', idx_RHS_EM = idx_RHS_EM, val_RHS_EM = val_RHS_EM, idx_RHS_heat=indexes_design_region_heat, val_RHS_heat=val_heater)
# Out:
# ---------------------------------------------------
# Solving for the unheated device ...
# ---------------------------------------------------
# EM FOM, for unheated device:  0.005207866850339844
# ---------------------------------------------------
# Solving for the heat propagation...
# ---------------------------------------------------
# ---------------------------------------------------
# Solving for the heated device ...
# ---------------------------------------------------
# EM FOM, for heated device:  0.004405218286356694

# %%
solver.plot_material_interpolation()

# %% [markdown]
# ## Optimization

# %%
dVs = solver.optimize_coupled_minmax(maxItr, tol, alg, idx_RHS_EM = idx_RHS_EM, val_RHS_EM = val_RHS_EM, idx_RHS_heat=indexes_design_region_heat, val_RHS_heat=val_heater)
# Out:
# FOM partial:  0.005207866850339844
# Elapsed time in iteration: 0 min 46 s
# ----------------------------------------------
# FOM1:  -2.2833401279156496
# FOM partial:  0.004401810126694128
# Elapsed time in iteration: 0 min 46 s
# ----------------------------------------------
# FOM2:  -2.35636869479209
# ----------------------------------------------
# Optimization iteration:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dVs = solver.optimize_coupled_minmax(maxItr, tol, alg, idx_RHS_EM = idx_RHS_EM, val_RHS_EM = val_RHS_EM, idx_RHS_heat=indexes_design_region_heat, val_RHS_heat=val_heater)
#
# File ~/Desktop/Projects/TOPS_lentghscale/solver.py:1183, in freq_top_opt_2D.optimize_coupled_minmax(self, maxItr, tol, algorithm, idx_RHS_EM, val_RHS_EM, idx_RHS_heat, val_RHS_heat)
#    1177 #self.opt = optimizer(m, n, p, LBdVs[:,np.newaxis], UBdVs[:,np.newaxis], f0, f, a0, a, c, d, self.maxItr, move, type_MMA="MMA")
#    1178
#    1179 # -----------------------------------------------------------------------------------
#    1180 # RUN OPTIMIZATION
#    1181 # -----------------------------------------------------------------------------------
#    1182 start = time.time() # we track the total optimization time
# -> 1183 self.dVs, self.FOM_list, self.constraint_1, self.constraint_2, self.constraint_3, self.constraint_4, self.constraint_5 = self.opt.optimize(self.dVs[:,np.newaxis])
#    1184 #self.dVhist = self.opt.dVhist
#    1185 end =  time.time()
#
# File ~/Desktop/Projects/TOPS_lentghscale/optimization.py:197, in optimizer.optimize(self, x, xold1, xold2, low, upp, raa0, raa, outit)
#     195 else:
#     196     for j in range(len(self.f)):
# --> 197         fvalnew[j]= self.f_no_d[j](xmma) # no gradient
#     200 # It is checked if the approximations are conservative:
#     201 conserv = concheck(self.m,epsimin,f0app,np.array([f0valnew]),fapp,fvalnew)
#
# File ~/Desktop/Projects/TOPS_lentghscale/solver.py:1051, in freq_top_opt_2D.optimize_coupled_minmax.<locals>.minmax_FOM_heated_constraint_no_sens(x)
#    1048 self.delta_n_wg = self.calculate_index_change(self.dis_heat.T, self.idx_wg_heat)
#    1050 E = self.dis_0.FEM_sol(x, self.FOM_type, self.idxdr_EM, self.idx_wg_EM,  self.physT, self.filThr_EM, solver, self.delta_n_wg, self.dis_heat, idx_RHS_EM, val_RHS_EM, eigval_num, self.eliminate_excitation)
# -> 1051 FOM, _, __ = self.dis_0.compute_FOM(self.idx_wg_EM, self.eliminate_excitation, idx_RHS_EM, self.physT)
#    1052 FOM = np.log10(FOM)
#    1054 return FOM+50-self.z
#
# File ~/Desktop/Projects/TOPS_lentghscale/discretization.py:737, in dis.compute_FOM(self, indexes_FOM, eliminate_excitation, idx_RHS, phy)
#     733     start = time.time()
#     735 P = scipy.sparse.csr_matrix((self.num_dof,self.num_dof), dtype='complex128')
# --> 737 P.setdiag(0. / self.num_dof)
#     738 #P.todok()
#     739 grid = np.reshape(np.arange(0,self.nElx * self.nEly), (self.nEly,self.nElx))
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/scipy/sparse/_base.py:1258, in spmatrix.setdiag(self, values, k)
#    1256 if (k > 0 and k >= N) or (k < 0 and -k >= M):
#    1257     raise ValueError("k exceeds matrix dimensions")
# -> 1258 self._setdiag(np.asarray(values), k)
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/scipy/sparse/_compressed.py:878, in _cs_matrix._setdiag(self, values, k)
#     875 if not broadcast:
#     876     values = values[:len(i)]
# --> 878 self[i, j] = values
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/scipy/sparse/_index.py:146, in IndexMixin.__setitem__(self, key, x)
#     144     return
#     145 x = x.reshape(i.shape)
# --> 146 self._set_arrayXarray(i, j, x)
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/scipy/sparse/_compressed.py:823, in _cs_matrix._set_arrayXarray(self, row, col, x)
#     821 def _set_arrayXarray(self, row, col, x):
#     822     i, j = self._swap((row, col))
# --> 823     self._set_many(i, j, x)
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/scipy/sparse/_compressed.py:936, in _cs_matrix._set_many(self, i, j, x)
#     934 j = j[mask]
#     935 j[j < 0] += N
# --> 936 self._insert_many(i, j, x[mask])
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/scipy/sparse/_compressed.py:997, in _cs_matrix._insert_many(self, i, j, x)
#     994 data_parts.append(self.data[start:stop])
#     996 # handle duplicate j: keep last setting
# --> 997 uj, uj_indptr = np.unique(j[js:je][::-1], return_index=True)
#     998 if len(uj) == je - js:
#     999     indices_parts.append(j[js:je])
#
# File <__array_function__ internals>:180, in unique(*args, **kwargs)
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/numpy/lib/arraysetops.py:340, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#     339 mask[:1] = True
# --> 340 if (equal_nan and aux.shape[0] > 0 and aux.dtype.kind in "cfmM" and
#     341         np.isnan(aux[-1])):
#     342     if aux.dtype.kind == "c":  # for complex all NaNs are considered equivalent
#     343         aux_firstnan = np.searchsorted(np.isnan(aux), True, side='left')
#
# KeyboardInterrupt:

# %%
solver.iteration_history(minmax=True)

# %%
print(solver.dis_heat.dFPST)

solver.plot_material_interpolation()

# %%
print(solver.constraint_3)

# %%
raise()

# %%
np.save("opt_variables_coupled.npy", dVs)
dVs = np.load("opt_variables_coupled.npy")

# %%
solver = freq_top_opt_2D( nElx_EM, 
                          nEly_EM,
                          nElx_heat, 
                          nEly_heat,
                          dVini,
                          w_core,
                          h_core,
                          n_metal,
                          k_r,
                          n_wg,
                          n_clad,
                          wl,
                          delta,
                          deltaT,  
                          fR,
                          eta,
                          1E9,
                          scaling,
                          vol_cons_val,
                          FOM_type,
                          indexes_wg_EM,
                          indexes_wg_heat,
                          indexes_design_region_EM,
                          indexes_design_region_heat,
                          heat_cons_val,
                          indexes_heating_EM,
                          indexes_heating_heat,
                          continuation_scheme= False,
                          heating_constraint= False,
                          volume_constraint= False,
                          eliminate_excitation= False,
                          dz=dz,
                          k_wg = k_wg,
                          k_clad = k_clad,
                          k_metal = k_metal,
                          debug=False,
                          logfile=True
                        )

# %%
solver.solve_coupled(dVs, solver='RHS', idx_RHS_EM = idx_RHS_EM, val_RHS_EM = val_RHS_EM, idx_RHS_heat=indexes_design_region_heat, val_RHS_heat=val_heater)

# %%
solver.plot_index_change()

# %%
solver.plot_material_interpolation()

# %%
deltamin = 3.80
deltamax = 3.86
N = 50

solver.prop_const_sweep_peak_coupled(deltamin, deltamax, delta, deltaT, N, dVs, idx_RHS_EM, val_RHS_EM, idx_RHS_heat=indexes_design_region_heat, val_RHS_heat=val_heater)
